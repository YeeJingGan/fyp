# %% [markdown]
# **Napari**

# %%
import napari
import torchio as tio

# Load MRI scan
image = tio.ScalarImage(r'C:\Users\hp\OneDrive\Documents\fyp\temp_file.nii.gz')

# Convert to NumPy
image_data = image.numpy()  # Remove channel dimension if needed [0]

# Launch interactive viewer
viewer = napari.Viewer()
viewer.add_image(image_data, name="MRI Scan")
napari.run()

# %%
import napari
import numpy as np

# %%
# Load .npz file
npz_path = r"C:\Users\hp\OneDrive\Documents\fyp\data\MSLUB-GT\patient01_consensus_gt.npz"  # Change to your actual file path
data = np.load(npz_path)

# Extract arrays (adjust the key based on your file)
image = data["data"]  # or 'ground_truth', 'mask' if needed

# Open Napari viewer
viewer = napari.Viewer()
viewer.add_image(image, name="MRI Scan")

# Start the Napari event loop
napari.run()

# %%
import torchio as tio

# %%
# Load MRI scan
image = tio.ScalarImage(r"C:\Users\hp\Downloads\MSLUB-GT\patient01_consensus_gt.nii.gz")

# Convert to NumPy
image_data = image.numpy()  # Remove channel dimension if needed [0]

# Open Napari viewer
viewer = napari.Viewer()
viewer.add_image(image_data, name="MRI Scan")

# Start the Napari event loop
napari.run()
