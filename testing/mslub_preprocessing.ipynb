# %%
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# %%
mri_path = r"C:\Users\hp\OneDrive\Documents\fyp\data\IXI-T1\IXI002-Guys-0828-T1.npz"

# %%
data = np.load(mri_path)
mri_volume = data['image']

# %%
mri_volume.shape
# Out:
# (1, 128, 128, 128)

# %%
type(mri_volume)
# Out:
# numpy.ndarray

# %% [markdown]
# **Tensor auto convert to numpy when save as npz**

# %%
gt_path = r"C:\Users\hp\Downloads\MSLUB-GT\patient01_consensus_gt.nii.gz"

# %%
img = nib.load(gt_path)
data = img.get_fdata()

unique_values = np.unique(data)
print(unique_values)
# Out:
# [0. 1.]

# %% [markdown]
# **MSLUB GT File only consist of 0 or 1**
