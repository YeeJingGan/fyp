# %%
# %pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\hp\onedrive\documents\fyp\.venv\lib\site-packages (4.11.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\hp\onedrive\documents\fyp\.venv\lib\site-packages (from pymongo[srv]) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pymongo 4.11.2 does not provide the extra 'srv'
#
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://ganyjwm22:7tYakelFSFD8GEhO@patientdata.wpssm.mongodb.net/?retryWrites=true&w=majority&appName=PatientData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
